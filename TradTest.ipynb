# %%
from chemlistem import get_ensemble_model
model = get_ensemble_model()
results = model.process("The morphine was dissolved in ethyl acetate.")
print(results)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# Fetching https://bitbucket.org/rscapplications/chemlistem/downloads/default_tradmodel_0.0.1.json at 2018-05-10 13:24:30.522827
# Fetched https://bitbucket.org/rscapplications/chemlistem/downloads/default_tradmodel_0.0.1.json at 2018-05-10 13:24:37.241059
# ...

# %%
from chemlistem import tradmodel
tm = tradmodel.TradModel()
tm.train("../BioCreative V.5 training set.txt", "../CEMP_BioCreative V.5 training set annot.tsv", "../glove.6B.300d.txt", "tradtest")
# Out:
# Reading corpus at 2018-05-10 14:16:41.321465
# Shufflesplit at 2018-05-10 14:16:41.321570
# Read annots at 2018-05-10 14:16:41.401516
# Read train seqs at 2018-05-10 14:16:41.623268
# Read test seqs at 2018-05-10 14:17:02.429966
# Corpus read at 2018-05-10 14:17:07.586621
# Embeddings read in: 28.788889169692993
# Make featurizer at 2018-05-10 14:17:37.294309
# Gather time: 1.5334644317626953
# Select from 128546 features
# Forest in 29.908665895462036
# Forest in 30.965862035751343
# Forest in 32.02741503715515
# Forest in 31.356679916381836
# Forest in 32.03181791305542
# 15402	1674	2645	0.877032144179028	0.9262163454967883
# Forest in 42.24241900444031
# Number words at 2018-05-10 14:22:06.955179
# Generate features at 2018-05-10 14:22:07.639993
# Generated features at 2018-05-10 14:22:36.274185
# Make train dict at 2018-05-10 14:22:36.274352
# Serialize at 2018-05-10 14:22:41.169357
# Epoch 0 start at 2018-05-10 14:22:59.657654
# Trained at 2018-05-10 14:30:29.612575
# ...

# %%
f = open("chemlistem/minimodel.py").read()
ff = f.replace("\t", "    ")
print(ff)
outf = open("chemlistem/minimodel_cudnn.py", "w")
outf.write(ff)
outf.close()
# Out:
# import time
# import io
# import sys
# import os
# import random
# import re
# import json
# import shutil
# from datetime import datetime
# from keras.layers.wrappers import Bidirectional, TimeDistributed
# from keras.layers.embeddings import Embedding
# from keras.layers.recurrent import LSTM
# from keras.layers.core import Dense, Dropout
# from keras.layers import Input
# from keras.models import Model, load_model
# import keras.regularizers
# import numpy as np
#
# from .utils import tobits, sobie_scores_to_char_ents, get_file
# from .corpusreader import CorpusReader
#
# charstr = "abcdefghijklmonpqrstuvwxyzABCDEFGHIJKLMNOPQRTSUVWXYZ0123456789.,-[](){};:'\"^$%=/\\<>@_*+?! "
# chard = {charstr[i]:i+1 for i in range(len(charstr))}
# charn = len(charstr) + 1
#
# defaultmodel = None
#
# def get_mini_model():
#     """
#     Gets the default pre-trained minimalist model, loading if necessary.
#
#     Returns:
#         An MiniModel
#     """
#     global defaultmodel
# ...

# %%
from chemlistem import neotradmodel
ntm = neotradmodel.NeoTradModel()
ntm.train("../BioCreative V.5 training set.txt", "../CEMP_BioCreative V.5 training set annot.tsv", "../glove.6B.300d.txt", "tradtest2")
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# Reading corpus at 2018-05-10 14:58:06.016913
# Shufflesplit at 2018-05-10 14:58:06.017065
# Read annots at 2018-05-10 14:58:06.079703
# Read train seqs at 2018-05-10 14:58:06.408211
# Read test seqs at 2018-05-10 14:58:28.100400
# ...

# %%
# include dropout
from chemlistem import neotradmodel
ntm = neotradmodel.NeoTradModel()
ntm.train("../BioCreative V.5 training set.txt", "../CEMP_BioCreative V.5 training set annot.tsv", "../glove.6B.300d.txt", "tradtest2")
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# Reading corpus at 2018-05-29 11:45:44.119339
# Shufflesplit at 2018-05-29 11:45:44.120077
# Read annots at 2018-05-29 11:45:44.282284
# Read train seqs at 2018-05-29 11:45:44.598721
# Read test seqs at 2018-05-29 11:46:07.225007
# ...

# %%
# include dropout, suffix-based unk
from chemlistem import neotradmodel
ntm = neotradmodel.NeoTradModel()
ntm.train("../BioCreative V.5 training set.txt", "../CEMP_BioCreative V.5 training set annot.tsv", "../glove.6B.300d.txt", "tradtest2")
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# Reading corpus at 2018-05-29 13:33:39.033439
# Shufflesplit at 2018-05-29 13:33:39.033551
# Read annots at 2018-05-29 13:33:39.093676
# Read train seqs at 2018-05-29 13:33:39.413472
# Read test seqs at 2018-05-29 13:34:00.923656
# ...

# %%
# include dropout, suffix-based unk, numbers, percentages
from chemlistem import neotradmodel
ntm = neotradmodel.NeoTradModel()
ntm.train("../BioCreative V.5 training set.txt", "../CEMP_BioCreative V.5 training set annot.tsv", "../glove.6B.300d.txt", "tradtest2")
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# Reading corpus at 2018-05-29 16:32:57.943315
# Shufflesplit at 2018-05-29 16:32:57.943435
# Read annots at 2018-05-29 16:32:58.013786
# Read train seqs at 2018-05-29 16:32:58.362950
# Read test seqs at 2018-05-29 16:33:19.871664
# ...

# %%
ntm

# %%
ntm.unkcache
# Out:
# {'6-(3-methoxycarbonyl': '*UNKyl*',
#  'amino-2,4(1Н': '*UNK*',
#  'ЗН)-pyrimidinedione': '*UNKone*',
#  'C12H11N3О4': '*UNK*',
#  'Curcumenol': '*UNKol*',
#  'sheared': '*UNKed*',
#  '0.1-100mg': '*UNK*',
#  '100-500nm': '*UNK*',
#  '4.0-9.0': '*UNK*',
#  'hihg': '*UNK*',
#  "(5R)-5-ethyl-9,10,difluoro-5-hydroxy-12-(2-trimethylsilylethyl)-4,5,13,15-tetrahydro-1H,3H-oxepino[3',4':6,7]-indoloizino[1,2-b]quinoline-3,15-dione": '*UNKone*',
#  'Levothyroxine': '*UNKine*',
#  'liothyronine': '*UNKine*',
#  '1-methyl-5-p-toluoylpyrrole-2-acetamidoacetic': '*UNKic*',
#  'guaiacyl': '*UNKyl*',
#  'valerenic': '*UNKic*',
#  'bloody': '*UNK*',
#  '(PTP)-1B': '*UNK*',
#  'symptomatically': '*UNKly*',
#  '136': '*UNKre_num*',
#  'broomcorn': '*UNK*',
#  'andrealizes': '*UNKs*',
#  '13-desmethoxy-18-hydroxyl-FK-520': '*UNK*',
#  'Polyketide': '*UNKide*',
#  'FK-520': '*UNK*',
#  '18-hydroxy-FK520': '*UNK*',
#  '18-hydroxy-FK-506': '*UNK*',
#  '15-80': '*UNK*',
#  'preconditions': '*UNKs*',
# ...

# %%
import re
pcr = re.compile("^-?[0-9]+(\\.[0-9]+)?%$")
pcr.match("1.1%")
# Out:
# <_sre.SRE_Match object; span=(0, 4), match='1.1%'>
